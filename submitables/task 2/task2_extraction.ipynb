# %% [markdown]
# # Task 2 · PDF-to-dataset extraction
# This notebook shells out to `Task2.py`, which parses the History of Services PDF and regenerates both CSV and XLSX tables under `task 2/output/`.

# %%
import pathlib, subprocess, sys
PROJECT_ROOT = pathlib.Path('..').resolve()
script = PROJECT_ROOT / 'Task2.py'
assert script.exists(), f'Missing script: {script}'
result = subprocess.run([sys.executable, str(script)], check=False)
print(f'Exit code: {result.returncode}')

# %% [markdown]
# ## Verification
# - Inspect `task 2/output/task2_records.csv` or open the XLSX sibling to validate row counts.
# - The console output reports the number of parsed station rows and the filesystem paths written.
