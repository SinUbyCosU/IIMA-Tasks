# %% [markdown]
# # Task 1 · FIBIS Scraper
# Run this notebook after placing the project root one level above. It imports `Task1.py`, executes the scraper, and stores 10 datasets inside folders that exactly match their FIBIS titles.

# %%
import pathlib, subprocess, sys
PROJECT_ROOT = pathlib.Path('..').resolve()
SCRIPT = PROJECT_ROOT / 'task 1' / 'Task1.py'
assert SCRIPT.exists(), f'Missing script: {SCRIPT}'
result = subprocess.run([sys.executable, str(SCRIPT)], check=False)
print(f'Exit code: {result.returncode}')

# %% [markdown]
# ## Expected outputs
# - Ten folders (`Overseas Births 1852`, …, `Z Mutiny List 1857`) each containing an identically named CSV file.
# - Console logs show pagination progress and any retries; reruns skip datasets that already exist.
