# %% [markdown]
# # Task 3 · Matrimonial ad extraction
# Run this notebook to execute `Task3.py`. The script iterates over the sample PDFs, performs OCR as needed, and rebuilds the CSV/XLSX outputs under `task 3/output/`.

# %%
import pathlib, subprocess, sys
PROJECT_ROOT = pathlib.Path('..').resolve()
script = PROJECT_ROOT / 'Task3.py'
assert script.exists(), f'Missing script: {script}'
result = subprocess.run([sys.executable, str(script)], check=False)
print(f'Exit code: {result.returncode}')

# %% [markdown]
# ## Output checks
# - `task 3/output/task3_ads.csv`
# - `task 3/output/task3_ads.xlsx`
# Review the `ad_text` column to confirm only matrimonial classifieds remain.
